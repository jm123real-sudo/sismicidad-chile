# %% [markdown]
# # Proyecto de Ciencia de Datos Reproducible
#
# ## Análisis de la Sismicidad en Chile
#
# ### Magíster en Ciencia de Datos e Inteligencia Artificial
#
# Integrantes
# José Miguel Serrano
# Jesús Fernández Urbaneja
# Osvaldo Rodrigo Moncada Peralta
# Evelyn Andrea Andrade Cárdenas
#
# ## Contexto del problema
#
# Chile es uno de los países con mayor actividad sísmica del mundo debido a la interacción entre las placas tectónicas de Nazca y Sudamericana. Comprender los patrones históricos de sismicidad permite identificar tendencias, analizar zonas de mayor ocurrencia y apoyar futuras investigaciones relacionadas con gestión de riesgos y prevención.
#
# ## Objetivo general
#
# Analizar registros históricos de actividad sísmica en Chile mediante un flujo de trabajo reproducible basado en herramientas de ciencia de datos, utilizando Python, Jupyter Notebook, Git y GitHub.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.3

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/seismic_data.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../../data/raw/seismic_data.csv")
#       4
#       5 df.head()
#
# File ~\mi_app\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## Exploración inicial del dataset
#
# La base de datos contiene registros sísmicos ocurridos en Chile. Las variables disponibles permiten analizar la ubicación geográfica de los eventos, su profundidad y magnitud.
#
# Las primeras observaciones muestran que el dataset contiene información temporal (fecha y hora) y variables numéricas relevantes para futuros análisis exploratorios y modelos predictivos.
#
# Esta etapa corresponde a la exploración inicial de los datos dentro del flujo de trabajo reproducible definido para la Fase 1 del proyecto.

# %% [markdown]
# ## Reflexión técnica preliminar
#
# El dataset fue seleccionado debido a su pertinencia con la problemática planteada, ya que contiene información histórica de actividad sísmica en Chile, uno de los países con mayor actividad tectónica del mundo.
#
# Las variables disponibles permiten estudiar la distribución espacial de los eventos, analizar la relación entre profundidad y magnitud, identificar patrones temporales y generar futuras visualizaciones exploratorias.
#
# Como desafío inicial, se observa que el dataset contiene información temporal que requerirá procesamiento para facilitar análisis por períodos, además de la necesidad de verificar la calidad de los registros y posibles valores atípicos.
#
# Las herramientas seleccionadas (Python, Jupyter Notebook, Git y GitHub) permiten desarrollar un flujo de trabajo reproducible, facilitando la documentación de decisiones, el control de versiones y la colaboración entre los integrantes del equipo.

# %% [markdown]
# ## Limitaciones identificadas
#
# Durante la exploración inicial se identifican las siguientes limitaciones potenciales:
#
# - El dataset no incluye información sobre daños materiales o humanos asociados a los eventos sísmicos.
# - La magnitud y profundidad permiten análisis geológicos, pero no necesariamente predicciones directas.
# - Será necesario validar la consistencia de fechas y registros históricos.
# - Pueden existir eventos extremos que requieran tratamiento especial durante el análisis exploratorio.

# %%
df.isnull().sum()

# %%
df.shape

# %% [markdown]
# ### Resumen inicial
#
# El dataset contiene 4.018 observaciones y 5 variables principales relacionadas con fecha, ubicación geográfica, profundidad y magnitud de eventos sísmicos ocurridos en Chile.
#
# Esta información constituye una base adecuada para desarrollar análisis exploratorios, visualizaciones y futuras etapas de modelamiento dentro del proyecto de ciencia de datos reproducible.

# %% [markdown]
# ## Conclusiones preliminares de la exploración
#
# La exploración inicial permitió identificar que el dataset contiene 4.018 registros sísmicos y 5 variables relevantes para el análisis.
#
# No se detectaron valores nulos en ninguna de las variables, lo que indica una adecuada calidad inicial de los datos para desarrollar análisis exploratorios y posteriores etapas de modelamiento.
#
# Las variables disponibles permiten estudiar la distribución geográfica de los eventos sísmicos, analizar magnitudes, profundidades y patrones temporales asociados a la actividad sísmica en Chile.
#
# Esta información proporciona una base sólida para continuar con las siguientes fases del proyecto bajo un enfoque de ciencia de datos reproducible.

# %%
def resumen_dataset(df):
    print("Cantidad de filas:", df.shape[0])
    print("Cantidad de columnas:", df.shape[1])
    print("Columnas disponibles:", df.columns.tolist())

resumen_dataset(df)
